# %%
from fastavro import parse_schema
from faker import Faker
import random
import string
from datetime import datetime
from geopy.geocoders import Nominatim
import geopy
from geopy.extra.rate_limiter import RateLimiter
geopy.geocoders.options.default_user_agent = "BDBA"
from tqdm import tqdm
import numpy as np

# %% [markdown]
# # 1. Define the data feeds

# %% [markdown]
# __Real-time vehicle information__

# %%
vehic_schema = {
    'doc': 'Traffic detection',
    'name': 'real-time_vehic_info',
    'namespace': 'traffic_detection.vehicle',
    'type': 'record',
    'fields': [
        {'name': 'vehicle_id', 'type': 'string'},
        {'name': 'datetime_utc', 'type': 'float'},
        {'name': 'latitude', 'type': 'float'},
        {'name': 'longitude', 'type': 'float'},
        {'name': 'accelerometer', 'type': 'int'},
        {'name': 'vehicle_type', 'type': ["null", {"type": "enum", "name":"vehicle_type",
                                                   "symbols": ["truck","taxi","bus","private_vehicle"]}]}#,
        #{'name': 'engine_state', 'type': ["null", {"type": "enum", "symbols": ["ON", "OFF"]}]}
    ],
}

parsed_vehic_schema = parse_schema(vehic_schema)
parsed_vehic_schema
# Out:
# {'type': 'record',
#  'doc': 'Traffic detection',
#  'name': 'traffic_detection.vehicle.real-time_vehic_info',
#  'fields': [{'name': 'vehicle_id', 'type': 'string'},
#   {'name': 'datetime_utc', 'type': 'float'},
#   {'name': 'latitude', 'type': 'float'},
#   {'name': 'longitude', 'type': 'float'},
#   {'name': 'accelerometer', 'type': 'int'},
#   {'name': 'vehicle_type',
#    'type': ['null',
#     {'type': 'enum',
#      'name': 'traffic_detection.vehicle.vehicle_type',
#      'symbols': ['truck', 'taxi', 'bus', 'private_vehicle']}]}],
#  '__fastavro_parsed': True,
#  '__named_schemas': {'traffic_detection.vehicle.real-time_vehic_info': {'type': 'record',
#    'doc': 'Traffic detection',
#    'name': 'traffic_detection.vehicle.real-time_vehic_info',
#    'fields': [{'name': 'vehicle_id', 'type': 'string'},
#     {'name': 'datetime_utc', 'type': 'float'},
#     {'name': 'latitude', 'type': 'float'},
#     {'name': 'longitude', 'type': 'float'},
#     {'name': 'accelerometer', 'type': 'int'},
#     {'name': 'vehicle_type',
#      'type': ['null',
#       {'type': 'enum',
#        'name': 'traffic_detection.vehicle.vehicle_type',
#        'symbols': ['truck', 'taxi', 'bus', 'private_vehicle']}]}]},
#   'traffic_detection.vehicle.vehicle_type': {'type': 'enum',
#    'name': 'traffic_detection.vehicle.vehicle_type',
#    'symbols': ['truck', 'taxi', 'bus', 'private_vehicle']}}}

# %% [markdown]
# __Road Information__

# %%
road_schema = {
    'doc': 'Traffic detection',
    'name': 'road_info',
    'namespace': 'traffic_detection.roads',
    'type': 'record',
    'fields': [
        {'name': 'road_name', 'type': 'string'},
        {'name': 'number_lanes', 'type': 'int'},
        {'name': 'min_speed', 'type': 'int'},
        {'name': 'has_bus_lane', 'type': ["null", {"type": "enum", "name":"has_bus_lane", "symbols": [0,1]}]}
    ],
}

parsed_road_schema = parse_schema(road_schema)
parsed_road_schema
# Out:
# {'type': 'record',
#  'doc': 'Traffic detection',
#  'name': 'traffic_detection.roads.road_info',
#  'fields': [{'name': 'road_name', 'type': 'string'},
#   {'name': 'number_lanes', 'type': 'int'},
#   {'name': 'min_speed', 'type': 'int'},
#   {'name': 'has_bus_lane',
#    'type': ['null',
#     {'type': 'enum',
#      'name': 'traffic_detection.roads.has_bus_lane',
#      'symbols': [0, 1]}]}],
#  '__fastavro_parsed': True,
#  '__named_schemas': {'traffic_detection.roads.road_info': {'type': 'record',
#    'doc': 'Traffic detection',
#    'name': 'traffic_detection.roads.road_info',
#    'fields': [{'name': 'road_name', 'type': 'string'},
#     {'name': 'number_lanes', 'type': 'int'},
#     {'name': 'min_speed', 'type': 'int'},
#     {'name': 'has_bus_lane',
#      'type': ['null',
#       {'type': 'enum',
#        'name': 'traffic_detection.roads.has_bus_lane',
#        'symbols': [0, 1]}]}]},
#   'traffic_detection.roads.has_bus_lane': {'type': 'enum',
#    'name': 'traffic_detection.roads.has_bus_lane',
#    'symbols': [0, 1]}}}

# %% [markdown]
# # 2. Generate Records

# %%
fake = Faker()
Faker.seed(2000)
random.seed(2000)

# %% [markdown]
# ## For vehicles

# %%
def generate_vehic_id():
    
    VOWELS = list("AEIOU")
    CONSONANTS = list(set(string.ascii_uppercase) - set(VOWELS))
    
    first_digit = str(fake.pyint(min_value=0, max_value=9, step=1))
    second_digit = str(fake.pyint(min_value=0, max_value=9, step=1))
    third_digit = str(fake.pyint(min_value=0, max_value=9, step=1))
    fourth_digit = str(fake.pyint(min_value=0, max_value=9, step=1))
    
    first_letter = random.choice(CONSONANTS)
    second_letter = random.choice(CONSONANTS)
    third_letter = random.choice(CONSONANTS)
    
    plate = first_digit+second_digit+third_digit+fourth_digit+' '+first_letter+second_letter+third_letter
    vehic_type = random.choice(["truck","taxi","bus","private_vehicle"])
    return(plate, vehic_type)

# %%
def vehicle_record(start_date, end_date):
    ids = generate_vehic_id()
    record = {
        u'vehicle_id': ids[0],
        u'datetime_utc': fake.date_time_between_dates(datetime_start=start_date, datetime_end=end_date).timestamp(),
        u'latitude': random.uniform(40.227240, 40.644740),
        u'longitude': random.uniform(-3.944317, -3.426800),
        u'accelerometer': fake.pyint(min_value=0, max_value=180, step=1),
        u'vehicle_type': ids[1],
    }
    return record

# %%
vehic_record_count = 100 # number of vehicle records

# %%
start_date = datetime(2020, 5, 3, 9, 1, 1) # year, month, day, hour, minute, second
end_date = datetime(2020, 5, 3, 9, 30, 1) # year, month, day, hour, minute, second
vehic_records = [vehicle_record(start_date, end_date) for _ in range(0, vehic_record_count)]

# %%
vehic_records
# Out:
# [{'vehicle_id': '7074 JYN',
#   'datetime_utc': 1588497903.0,
#   'latitude': 40.52135629950477,
#   'longitude': -3.8507919185827992,
#   'accelerometer': 46,
#   'vehicle_type': 'bus'},
#  {'vehicle_id': '9263 KDM',
#   'datetime_utc': 1588498142.0,
#   'latitude': 40.57007465863976,
#   'longitude': -3.6071938480844157,
#   'accelerometer': 166,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '2895 ZTV',
#   'datetime_utc': 1588497165.0,
#   'latitude': 40.44546287335486,
#   'longitude': -3.5125486436404882,
#   'accelerometer': 133,
#   'vehicle_type': 'bus'},
#  {'vehicle_id': '6030 HXH',
#   'datetime_utc': 1588497698.0,
#   'latitude': 40.30815660225567,
#   'longitude': -3.909501918887368,
#   'accelerometer': 162,
#   'vehicle_type': 'private_vehicle'},
#  {'vehicle_id': '9731 YWN',
#   'datetime_utc': 1588497903.0,
#   'latitude': 40.47042101938655,
#   'longitude': -3.4346389045623913,
#   'accelerometer': 8,
#   'vehicle_type': 'truck'},
#  {'vehicle_id': '3719 WQR',
#   'datetime_utc': 1588497968.0,
#   'latitude': 40.41651432933575,
#   'longitude': -3.916999450399277,
#   'accelerometer': 56,
#   'vehicle_type': 'bus'},
#  {'vehicle_id': '8147 QFX',
#   'datetime_utc': 1588497317.0,
#   'latitude': 40.42268107917671,
#   'longitude': -3.482537435543491,
#   'accelerometer': 13,
#   'vehicle_type': 'private_vehicle'},
#  {'vehicle_id': '5823 YCR',
#   'datetime_utc': 1588497266.0,
#   'latitude': 40.55716134032274,
#   'longitude': -3.633252828413418,
#   'accelerometer': 119,
#   'vehicle_type': 'bus'},
#  {'vehicle_id': '9004 RYR',
#   'datetime_utc': 1588496680.0,
#   'latitude': 40.44211686617688,
#   'longitude': -3.8296335336151293,
#   'accelerometer': 164,
#   'vehicle_type': 'truck'},
#  {'vehicle_id': '4990 XZH',
#   'datetime_utc': 1588496699.0,
#   'latitude': 40.278834809179024,
#   'longitude': -3.8680087495362443,
#   'accelerometer': 10,
#   'vehicle_type': 'truck'},
#  {'vehicle_id': '1186 DCW',
#   'datetime_utc': 1588496914.0,
#   'latitude': 40.60154028310262,
#   'longitude': -3.665103590957575,
#   'accelerometer': 53,
#   'vehicle_type': 'truck'},
#  {'vehicle_id': '3800 QZK',
#   'datetime_utc': 1588496714.0,
#   'latitude': 40.55624580290674,
#   'longitude': -3.830169858736617,
#   'accelerometer': 37,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '2438 HJV',
#   'datetime_utc': 1588498085.0,
#   'latitude': 40.365424474175065,
#   'longitude': -3.5055162695912654,
#   'accelerometer': 158,
#   'vehicle_type': 'truck'},
#  {'vehicle_id': '1898 DMC',
#   'datetime_utc': 1588498193.0,
#   'latitude': 40.45153290902815,
#   'longitude': -3.7322600335322087,
#   'accelerometer': 137,
#   'vehicle_type': 'private_vehicle'},
#  {'vehicle_id': '2390 MDK',
#   'datetime_utc': 1588497365.0,
#   'latitude': 40.24313789031098,
#   'longitude': -3.5148746715156807,
#   'accelerometer': 81,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '0502 NFZ',
#   'datetime_utc': 1588497256.0,
#   'latitude': 40.59672937736434,
#   'longitude': -3.764400132573398,
#   'accelerometer': 73,
#   'vehicle_type': 'bus'},
#  {'vehicle_id': '7866 TBN',
#   'datetime_utc': 1588496756.0,
#   'latitude': 40.34332621872282,
#   'longitude': -3.6009947179145136,
#   'accelerometer': 161,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '3030 DHT',
#   'datetime_utc': 1588497874.0,
#   'latitude': 40.62934108007232,
#   'longitude': -3.5576133972418025,
#   'accelerometer': 124,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '2895 VKQ',
#   'datetime_utc': 1588498128.0,
#   'latitude': 40.296686171830316,
#   'longitude': -3.730661821063543,
#   'accelerometer': 88,
#   'vehicle_type': 'private_vehicle'},
#  {'vehicle_id': '3967 CML',
#   'datetime_utc': 1588496755.0,
#   'latitude': 40.295571690880024,
#   'longitude': -3.822781484677027,
#   'accelerometer': 71,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '2093 XBZ',
#   'datetime_utc': 1588497619.0,
#   'latitude': 40.555456356417395,
#   'longitude': -3.5098996785802057,
#   'accelerometer': 80,
#   'vehicle_type': 'bus'},
#  {'vehicle_id': '8626 KRP',
#   'datetime_utc': 1588497171.0,
#   'latitude': 40.49199416321875,
#   'longitude': -3.574880397779795,
#   'accelerometer': 78,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '6922 CKB',
#   'datetime_utc': 1588498167.0,
#   'latitude': 40.24278794581995,
#   'longitude': -3.8752882313121058,
#   'accelerometer': 60,
#   'vehicle_type': 'private_vehicle'},
#  {'vehicle_id': '0368 GXT',
#   'datetime_utc': 1588497677.0,
#   'latitude': 40.644660888396395,
#   'longitude': -3.7428193561163696,
#   'accelerometer': 77,
#   'vehicle_type': 'private_vehicle'},
#  {'vehicle_id': '0711 RXL',
#   'datetime_utc': 1588496869.0,
#   'latitude': 40.608376368138984,
#   'longitude': -3.732645244041724,
#   'accelerometer': 162,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '5646 HPM',
#   'datetime_utc': 1588497323.0,
#   'latitude': 40.28231011390044,
#   'longitude': -3.943851642808249,
#   'accelerometer': 9,
#   'vehicle_type': 'bus'},
#  {'vehicle_id': '3255 ZYP',
#   'datetime_utc': 1588496879.0,
#   'latitude': 40.227314141490545,
#   'longitude': -3.8213862707865354,
#   'accelerometer': 154,
#   'vehicle_type': 'truck'},
#  {'vehicle_id': '8873 KJC',
#   'datetime_utc': 1588497258.0,
#   'latitude': 40.618205498772795,
#   'longitude': -3.8861302158396955,
#   'accelerometer': 29,
#   'vehicle_type': 'private_vehicle'},
#  {'vehicle_id': '3929 WHZ',
#   'datetime_utc': 1588497298.0,
#   'latitude': 40.52668610921478,
#   'longitude': -3.537889998829901,
#   'accelerometer': 1,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '1652 BQJ',
#   'datetime_utc': 1588497544.0,
#   'latitude': 40.63332388496272,
#   'longitude': -3.9013988992738566,
#   'accelerometer': 0,
#   'vehicle_type': 'truck'},
#  {'vehicle_id': '1801 PJG',
#   'datetime_utc': 1588497578.0,
#   'latitude': 40.64187900914358,
#   'longitude': -3.6225616621196552,
#   'accelerometer': 163,
#   'vehicle_type': 'private_vehicle'},
#  {'vehicle_id': '8103 VRN',
#   'datetime_utc': 1588497953.0,
#   'latitude': 40.34921486626371,
#   'longitude': -3.7895102753064145,
#   'accelerometer': 166,
#   'vehicle_type': 'truck'},
#  {'vehicle_id': '7477 PKB',
#   'datetime_utc': 1588496691.0,
#   'latitude': 40.43006869863203,
#   'longitude': -3.5268612303459337,
#   'accelerometer': 18,
#   'vehicle_type': 'bus'},
#  {'vehicle_id': '3083 QTH',
#   'datetime_utc': 1588497929.0,
#   'latitude': 40.272043486373015,
#   'longitude': -3.842761352027243,
#   'accelerometer': 122,
#   'vehicle_type': 'truck'},
#  {'vehicle_id': '6871 XLT',
#   'datetime_utc': 1588496544.0,
#   'latitude': 40.56955975157563,
#   'longitude': -3.756285956344227,
#   'accelerometer': 21,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '0175 VYQ',
#   'datetime_utc': 1588497309.0,
#   'latitude': 40.5103221995311,
#   'longitude': -3.752879299973984,
#   'accelerometer': 159,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '5178 WVZ',
#   'datetime_utc': 1588496592.0,
#   'latitude': 40.44859846139964,
#   'longitude': -3.7425955988168034,
#   'accelerometer': 74,
#   'vehicle_type': 'bus'},
#  {'vehicle_id': '4816 KBV',
#   'datetime_utc': 1588497070.0,
#   'latitude': 40.530876076452444,
#   'longitude': -3.7692322279451878,
#   'accelerometer': 124,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '7189 MTL',
#   'datetime_utc': 1588496520.0,
#   'latitude': 40.45700696005396,
#   'longitude': -3.4509858468830106,
#   'accelerometer': 143,
#   'vehicle_type': 'bus'},
#  {'vehicle_id': '1153 LJP',
#   'datetime_utc': 1588497000.0,
#   'latitude': 40.2980134326708,
#   'longitude': -3.879461846744514,
#   'accelerometer': 53,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '9935 FCX',
#   'datetime_utc': 1588496482.0,
#   'latitude': 40.23613389971729,
#   'longitude': -3.743092788481494,
#   'accelerometer': 81,
#   'vehicle_type': 'truck'},
#  {'vehicle_id': '0825 TZS',
#   'datetime_utc': 1588497128.0,
#   'latitude': 40.40750016258719,
#   'longitude': -3.508534226625131,
#   'accelerometer': 63,
#   'vehicle_type': 'private_vehicle'},
#  {'vehicle_id': '5858 WNJ',
#   'datetime_utc': 1588497259.0,
#   'latitude': 40.29367104769539,
#   'longitude': -3.8667660725674824,
#   'accelerometer': 36,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '6535 HGZ',
#   'datetime_utc': 1588496715.0,
#   'latitude': 40.53690134359674,
#   'longitude': -3.476631363777201,
#   'accelerometer': 102,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '9958 WSG',
#   'datetime_utc': 1588497811.0,
#   'latitude': 40.36070255711437,
#   'longitude': -3.4421907570323578,
#   'accelerometer': 144,
#   'vehicle_type': 'bus'},
#  {'vehicle_id': '7122 QBH',
#   'datetime_utc': 1588496717.0,
#   'latitude': 40.29100543164117,
#   'longitude': -3.8649889949905876,
#   'accelerometer': 167,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '2430 FSC',
#   'datetime_utc': 1588496504.0,
#   'latitude': 40.27207541549019,
#   'longitude': -3.55008608790955,
#   'accelerometer': 55,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '6498 TKN',
#   'datetime_utc': 1588497032.0,
#   'latitude': 40.502488400275425,
#   'longitude': -3.736948326613803,
#   'accelerometer': 99,
#   'vehicle_type': 'private_vehicle'},
#  {'vehicle_id': '6377 KBD',
#   'datetime_utc': 1588496798.0,
#   'latitude': 40.45793449857518,
#   'longitude': -3.777262513996311,
#   'accelerometer': 40,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '2205 TGW',
#   'datetime_utc': 1588497922.0,
#   'latitude': 40.60864298513324,
#   'longitude': -3.7730137907144323,
#   'accelerometer': 139,
#   'vehicle_type': 'bus'},
#  {'vehicle_id': '3243 HKB',
#   'datetime_utc': 1588496982.0,
#   'latitude': 40.561028563743484,
#   'longitude': -3.9038296659794742,
#   'accelerometer': 91,
#   'vehicle_type': 'bus'},
#  {'vehicle_id': '5548 QTG',
#   'datetime_utc': 1588497880.0,
#   'latitude': 40.56976208297574,
#   'longitude': -3.8934008922318393,
#   'accelerometer': 111,
#   'vehicle_type': 'truck'},
#  {'vehicle_id': '0822 NFF',
#   'datetime_utc': 1588497882.0,
#   'latitude': 40.436054325430575,
#   'longitude': -3.9068704105460763,
#   'accelerometer': 39,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '3244 YSY',
#   'datetime_utc': 1588498110.0,
#   'latitude': 40.47828713572721,
#   'longitude': -3.5717858643953853,
#   'accelerometer': 38,
#   'vehicle_type': 'truck'},
#  {'vehicle_id': '1976 GDG',
#   'datetime_utc': 1588497811.0,
#   'latitude': 40.48256937781472,
#   'longitude': -3.5205819417270914,
#   'accelerometer': 83,
#   'vehicle_type': 'truck'},
#  {'vehicle_id': '6629 JNZ',
#   'datetime_utc': 1588496844.0,
#   'latitude': 40.45651657313247,
#   'longitude': -3.452399861729674,
#   'accelerometer': 141,
#   'vehicle_type': 'bus'},
#  {'vehicle_id': '5529 NHC',
#   'datetime_utc': 1588497203.0,
#   'latitude': 40.51347180676369,
#   'longitude': -3.6033047927588946,
#   'accelerometer': 58,
#   'vehicle_type': 'bus'},
#  {'vehicle_id': '4850 QKH',
#   'datetime_utc': 1588496466.0,
#   'latitude': 40.406188095825065,
#   'longitude': -3.6629295943105515,
#   'accelerometer': 163,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '6512 QBN',
#   'datetime_utc': 1588498060.0,
#   'latitude': 40.35463474269492,
#   'longitude': -3.659259439207084,
#   'accelerometer': 135,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '9501 MLY',
#   'datetime_utc': 1588496662.0,
#   'latitude': 40.28918741747364,
#   'longitude': -3.6730996693167506,
#   'accelerometer': 114,
#   'vehicle_type': 'private_vehicle'},
#  {'vehicle_id': '7222 NWJ',
#   'datetime_utc': 1588497485.0,
#   'latitude': 40.34752225703527,
#   'longitude': -3.470644838679025,
#   'accelerometer': 80,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '1040 NQT',
#   'datetime_utc': 1588496519.0,
#   'latitude': 40.62634822822605,
#   'longitude': -3.4704133433848594,
#   'accelerometer': 153,
#   'vehicle_type': 'private_vehicle'},
#  {'vehicle_id': '5258 QMQ',
#   'datetime_utc': 1588497642.0,
#   'latitude': 40.30874180715919,
#   'longitude': -3.474788205733442,
#   'accelerometer': 24,
#   'vehicle_type': 'bus'},
#  {'vehicle_id': '9377 KXN',
#   'datetime_utc': 1588497552.0,
#   'latitude': 40.403359068926655,
#   'longitude': -3.847730245148704,
#   'accelerometer': 160,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '5847 LDX',
#   'datetime_utc': 1588496520.0,
#   'latitude': 40.592868499718804,
#   'longitude': -3.6245074795947714,
#   'accelerometer': 76,
#   'vehicle_type': 'truck'},
#  {'vehicle_id': '5558 BTC',
#   'datetime_utc': 1588497756.0,
#   'latitude': 40.5469872544826,
#   'longitude': -3.690294466815954,
#   'accelerometer': 0,
#   'vehicle_type': 'private_vehicle'},
#  {'vehicle_id': '2618 KGX',
#   'datetime_utc': 1588497101.0,
#   'latitude': 40.39060991460699,
#   'longitude': -3.531483521405759,
#   'accelerometer': 133,
#   'vehicle_type': 'bus'},
#  {'vehicle_id': '6724 MYK',
#   'datetime_utc': 1588497276.0,
#   'latitude': 40.40309928713346,
#   'longitude': -3.5177970167367087,
#   'accelerometer': 141,
#   'vehicle_type': 'private_vehicle'},
#  {'vehicle_id': '6906 TSP',
#   'datetime_utc': 1588496764.0,
#   'latitude': 40.463415586190195,
#   'longitude': -3.930369910838794,
#   'accelerometer': 63,
#   'vehicle_type': 'bus'},
#  {'vehicle_id': '8573 JRJ',
#   'datetime_utc': 1588497366.0,
#   'latitude': 40.6199029480305,
#   'longitude': -3.653920725235404,
#   'accelerometer': 41,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '4707 ZBD',
#   'datetime_utc': 1588497489.0,
#   'latitude': 40.507607481225385,
#   'longitude': -3.889587504293329,
#   'accelerometer': 155,
#   'vehicle_type': 'private_vehicle'},
#  {'vehicle_id': '8628 YFB',
#   'datetime_utc': 1588497233.0,
#   'latitude': 40.282568297919525,
#   'longitude': -3.504817548548244,
#   'accelerometer': 134,
#   'vehicle_type': 'private_vehicle'},
#  {'vehicle_id': '5363 XQS',
#   'datetime_utc': 1588497795.0,
#   'latitude': 40.602686780407126,
#   'longitude': -3.722772952142165,
#   'accelerometer': 168,
#   'vehicle_type': 'bus'},
#  {'vehicle_id': '3736 XXY',
#   'datetime_utc': 1588497939.0,
#   'latitude': 40.56353238522604,
#   'longitude': -3.608126928667154,
#   'accelerometer': 47,
#   'vehicle_type': 'private_vehicle'},
#  {'vehicle_id': '9231 DCN',
#   'datetime_utc': 1588497401.0,
#   'latitude': 40.56538858790488,
#   'longitude': -3.4287133884487977,
#   'accelerometer': 158,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '0694 YNK',
#   'datetime_utc': 1588497299.0,
#   'latitude': 40.48858984830837,
#   'longitude': -3.9393272257098846,
#   'accelerometer': 164,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '7538 XXD',
#   'datetime_utc': 1588497045.0,
#   'latitude': 40.500573374676684,
#   'longitude': -3.807641414628241,
#   'accelerometer': 100,
#   'vehicle_type': 'truck'},
#  {'vehicle_id': '9607 KRX',
#   'datetime_utc': 1588497323.0,
#   'latitude': 40.30642404788038,
#   'longitude': -3.9399290884139067,
#   'accelerometer': 45,
#   'vehicle_type': 'bus'},
#  {'vehicle_id': '8941 QRP',
#   'datetime_utc': 1588497205.0,
#   'latitude': 40.36616258608104,
#   'longitude': -3.9399611090007056,
#   'accelerometer': 144,
#   'vehicle_type': 'truck'},
#  {'vehicle_id': '2057 XLX',
#   'datetime_utc': 1588496680.0,
#   'latitude': 40.507202523607496,
#   'longitude': -3.9440086544315713,
#   'accelerometer': 118,
#   'vehicle_type': 'private_vehicle'},
#  {'vehicle_id': '3828 YYP',
#   'datetime_utc': 1588497305.0,
#   'latitude': 40.60016253406453,
#   'longitude': -3.888336414960293,
#   'accelerometer': 37,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '6515 FGN',
#   'datetime_utc': 1588496565.0,
#   'latitude': 40.5471618927841,
#   'longitude': -3.655073388499561,
#   'accelerometer': 45,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '6726 ZBD',
#   'datetime_utc': 1588498200.0,
#   'latitude': 40.235096042803406,
#   'longitude': -3.5323475507208726,
#   'accelerometer': 55,
#   'vehicle_type': 'private_vehicle'},
#  {'vehicle_id': '8444 JBS',
#   'datetime_utc': 1588497337.0,
#   'latitude': 40.29846572136911,
#   'longitude': -3.503740257937815,
#   'accelerometer': 55,
#   'vehicle_type': 'private_vehicle'},
#  {'vehicle_id': '3067 JSZ',
#   'datetime_utc': 1588497791.0,
#   'latitude': 40.38039813114905,
#   'longitude': -3.6959209569499714,
#   'accelerometer': 63,
#   'vehicle_type': 'bus'},
#  {'vehicle_id': '2473 SFH',
#   'datetime_utc': 1588498119.0,
#   'latitude': 40.30309087452065,
#   'longitude': -3.523339577438048,
#   'accelerometer': 12,
#   'vehicle_type': 'private_vehicle'},
#  {'vehicle_id': '7929 JSH',
#   'datetime_utc': 1588496480.0,
#   'latitude': 40.502011879411526,
#   'longitude': -3.575652873026401,
#   'accelerometer': 3,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '3321 FBS',
#   'datetime_utc': 1588497801.0,
#   'latitude': 40.46770008453608,
#   'longitude': -3.615350336507301,
#   'accelerometer': 175,
#   'vehicle_type': 'truck'},
#  {'vehicle_id': '4413 BPT',
#   'datetime_utc': 1588498064.0,
#   'latitude': 40.39251564558988,
#   'longitude': -3.7728260609322013,
#   'accelerometer': 92,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '3104 BJB',
#   'datetime_utc': 1588498201.0,
#   'latitude': 40.32247929027208,
#   'longitude': -3.7839326786129086,
#   'accelerometer': 129,
#   'vehicle_type': 'private_vehicle'},
#  {'vehicle_id': '1115 WZR',
#   'datetime_utc': 1588497977.0,
#   'latitude': 40.51736524615427,
#   'longitude': -3.7545482296527215,
#   'accelerometer': 2,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '3936 QBM',
#   'datetime_utc': 1588497834.0,
#   'latitude': 40.54600814541259,
#   'longitude': -3.59043366348307,
#   'accelerometer': 0,
#   'vehicle_type': 'truck'},
#  {'vehicle_id': '3001 GCL',
#   'datetime_utc': 1588496719.0,
#   'latitude': 40.469752058786625,
#   'longitude': -3.891283053312511,
#   'accelerometer': 157,
#   'vehicle_type': 'bus'},
#  {'vehicle_id': '1257 SRM',
#   'datetime_utc': 1588497579.0,
#   'latitude': 40.37946118905957,
#   'longitude': -3.492814615316956,
#   'accelerometer': 52,
#   'vehicle_type': 'private_vehicle'},
#  {'vehicle_id': '4886 SPW',
#   'datetime_utc': 1588496760.0,
#   'latitude': 40.5328324557907,
#   'longitude': -3.7064859888560795,
#   'accelerometer': 112,
#   'vehicle_type': 'taxi'},
#  {'vehicle_id': '0617 WYH',
#   'datetime_utc': 1588497940.0,
#   'latitude': 40.6361423565985,
#   'longitude': -3.6400538882060283,
#   'accelerometer': 107,
#   'vehicle_type': 'private_vehicle'},
#  {'vehicle_id': '4728 YFV',
#   'datetime_utc': 1588497669.0,
#   'latitude': 40.48422297787726,
#   'longitude': -3.9330140704789214,
#   'accelerometer': 114,
#   'vehicle_type': 'private_vehicle'},
#  {'vehicle_id': '4855 DMF',
#   'datetime_utc': 1588497443.0,
#   'latitude': 40.257045620126576,
#   'longitude': -3.8653671225727657,
#   'accelerometer': 67,
#   'vehicle_type': 'bus'},
#  {'vehicle_id': '2072 DCD',
#   'datetime_utc': 1588498126.0,
#   'latitude': 40.347081665001674,
#   'longitude': -3.709896086352776,
#   'accelerometer': 170,
#   'vehicle_type': 'bus'},
#  {'vehicle_id': '7402 LMS',
#   'datetime_utc': 1588497808.0,
#   'latitude': 40.32779120536886,
#   'longitude': -3.8905784328495776,
#   'accelerometer': 152,
#   'vehicle_type': 'taxi'}]

# %% [markdown]
# __Road names from vehicles coordinates__

# %%
def road_from_coord(lat, lon):
    coordinates= str(lat)+ ','+str(lon)
    #10 mins maximum timeout to prevent being blocked
    locator = Nominatim(timeout=10)
    rgeocode = RateLimiter(locator.reverse, min_delay_seconds=0.001)
    location = rgeocode(coordinates)
    return(location)

# %%
road_names = []
final_vehics = []
for i in tqdm(vehic_records):
    location = road_from_coord(i['latitude'],i['longitude'])
    try:
        road_names.append(location.raw['address']['road'])
        final_vehics.append(i)
    except KeyError:
        continue
# Out:
# 100%|██████████| 100/100 [00:49<00:00,  2.02it/s]

# %% [markdown]
# ## For roads

# %%
road_names= np.unique(road_names)

# %%
def road_record(road_name):
    record = {
        u'road_name': road_name,
        u'number_lanes': fake.pyint(min_value=1, max_value=4, step=1),
        u'min_speed': random.choice([25,50,60]),
        u'has_bus_lane': random.choice([0,1]),
    }
    return record

# %%
road_records = [road_record(name) for name in road_names]

# %%
road_records
# Out:
# [{'road_name': 'AP-41', 'number_lanes': 4, 'min_speed': 60, 'has_bus_lane': 0},
#  {'road_name': 'Autopista radial RM-1',
#   'number_lanes': 2,
#   'min_speed': 50,
#   'has_bus_lane': 0},
#  {'road_name': 'Autovía del Este',
#   'number_lanes': 4,
#   'min_speed': 25,
#   'has_bus_lane': 1},
#  {'road_name': 'Autovía del Suroeste',
#   'number_lanes': 3,
#   'min_speed': 50,
#   'has_bus_lane': 1},
#  {'road_name': 'Avenida Antonio Machado',
#   'number_lanes': 1,
#   'min_speed': 50,
#   'has_bus_lane': 0},
#  {'road_name': 'Avenida Nuestra Señora del Retamar',
#   'number_lanes': 4,
#   'min_speed': 60,
#   'has_bus_lane': 0},
#  {'road_name': 'Avenida Puente Cultural',
#   'number_lanes': 1,
#   'min_speed': 25,
#   'has_bus_lane': 0},
#  {'road_name': 'Avenida de Madrid',
#   'number_lanes': 2,
#   'min_speed': 50,
#   'has_bus_lane': 0},
#  {'road_name': 'Avenida de la Hispanidad',
#   'number_lanes': 4,
#   'min_speed': 50,
#   'has_bus_lane': 0},
#  {'road_name': 'Avenida de la Tierra',
#   'number_lanes': 4,
#   'min_speed': 25,
#   'has_bus_lane': 0},
#  {'road_name': 'Avenida de los Premios Nobel',
#   'number_lanes': 3,
#   'min_speed': 50,
#   'has_bus_lane': 1},
#  {'road_name': 'Bajada del Tronco',
#   'number_lanes': 4,
#   'min_speed': 60,
#   'has_bus_lane': 1},
#  {'road_name': 'Calle 30',
#   'number_lanes': 4,
#   'min_speed': 60,
#   'has_bus_lane': 0},
#  {'road_name': 'Calle Alcalá',
#   'number_lanes': 4,
#   'min_speed': 25,
#   'has_bus_lane': 1},
#  {'road_name': 'Calle Beltrand Russell',
#   'number_lanes': 4,
#   'min_speed': 60,
#   'has_bus_lane': 0},
#  {'road_name': 'Calle Fuente del Rey',
#   'number_lanes': 2,
#   'min_speed': 50,
#   'has_bus_lane': 1},
#  {'road_name': 'Calle Lagunas de Ruidera',
#   'number_lanes': 3,
#   'min_speed': 50,
#   'has_bus_lane': 0},
#  {'road_name': 'Calle Madroño',
#   'number_lanes': 2,
#   'min_speed': 50,
#   'has_bus_lane': 0},
#  {'road_name': 'Calle Milano',
#   'number_lanes': 1,
#   'min_speed': 60,
#   'has_bus_lane': 1},
#  {'road_name': 'Calle Pavo Real',
#   'number_lanes': 2,
#   'min_speed': 50,
#   'has_bus_lane': 1},
#  {'road_name': 'Calle Profesor Juan Iglesias',
#   'number_lanes': 3,
#   'min_speed': 25,
#   'has_bus_lane': 1},
#  {'road_name': 'Calle Valle del Roncal',
#   'number_lanes': 4,
#   'min_speed': 50,
#   'has_bus_lane': 0},
#  {'road_name': 'Calle de Francia',
#   'number_lanes': 4,
#   'min_speed': 50,
#   'has_bus_lane': 0},
#  {'road_name': 'Calle de Mirasierra Altos de Jarama',
#   'number_lanes': 4,
#   'min_speed': 50,
#   'has_bus_lane': 1},
#  {'road_name': 'Calle de Simón González',
#   'number_lanes': 1,
#   'min_speed': 50,
#   'has_bus_lane': 0},
#  {'road_name': 'Calle de la Artesanía',
#   'number_lanes': 1,
#   'min_speed': 60,
#   'has_bus_lane': 0},
#  {'road_name': 'Calle de la Cañada',
#   'number_lanes': 1,
#   'min_speed': 60,
#   'has_bus_lane': 0},
#  {'road_name': 'Calle de las Azucenas',
#   'number_lanes': 3,
#   'min_speed': 60,
#   'has_bus_lane': 0},
#  {'road_name': 'Calle de los Fresnos',
#   'number_lanes': 3,
#   'min_speed': 60,
#   'has_bus_lane': 0},
#  {'road_name': 'Calle de los Geranios',
#   'number_lanes': 3,
#   'min_speed': 25,
#   'has_bus_lane': 1},
#  {'road_name': 'Calle del Marqués de la Valdavia',
#   'number_lanes': 1,
#   'min_speed': 60,
#   'has_bus_lane': 1},
#  {'road_name': 'Camino Particular Corsini',
#   'number_lanes': 3,
#   'min_speed': 60,
#   'has_bus_lane': 1},
#  {'road_name': 'Camino Soto San Marcos',
#   'number_lanes': 1,
#   'min_speed': 25,
#   'has_bus_lane': 1},
#  {'road_name': 'Camino Vecinal de Moraleja de Enmedio a Móstoles',
#   'number_lanes': 4,
#   'min_speed': 50,
#   'has_bus_lane': 0},
#  {'road_name': 'Camino de Cantos Blancos',
#   'number_lanes': 4,
#   'min_speed': 25,
#   'has_bus_lane': 0},
#  {'road_name': 'Camino de Griñón a Parla',
#   'number_lanes': 3,
#   'min_speed': 50,
#   'has_bus_lane': 0},
#  {'road_name': 'Camino de Manzanares',
#   'number_lanes': 2,
#   'min_speed': 60,
#   'has_bus_lane': 0},
#  {'road_name': 'Camino de Sacedón',
#   'number_lanes': 3,
#   'min_speed': 50,
#   'has_bus_lane': 1},
#  {'road_name': 'Camino de Salcedo',
#   'number_lanes': 1,
#   'min_speed': 25,
#   'has_bus_lane': 1},
#  {'road_name': 'Camino del Canal de Isabel II',
#   'number_lanes': 2,
#   'min_speed': 60,
#   'has_bus_lane': 1},
#  {'road_name': 'Carretera Villaviciosa - Arganda',
#   'number_lanes': 2,
#   'min_speed': 60,
#   'has_bus_lane': 1},
#  {'road_name': 'Carretera Vía de servicio A-6',
#   'number_lanes': 4,
#   'min_speed': 50,
#   'has_bus_lane': 0},
#  {'road_name': 'Carretera de Boadilla a Brunete',
#   'number_lanes': 2,
#   'min_speed': 25,
#   'has_bus_lane': 1},
#  {'road_name': 'Carretera de Circunvalación',
#   'number_lanes': 2,
#   'min_speed': 25,
#   'has_bus_lane': 0},
#  {'road_name': 'Carretera de Colmenar Viejo',
#   'number_lanes': 1,
#   'min_speed': 60,
#   'has_bus_lane': 1},
#  {'road_name': 'Carretera de Daganzo',
#   'number_lanes': 1,
#   'min_speed': 25,
#   'has_bus_lane': 1},
#  {'road_name': 'Carretera de El Pardo a El Goloso',
#   'number_lanes': 4,
#   'min_speed': 25,
#   'has_bus_lane': 1},
#  {'road_name': 'Carretera de Fuencarral a El Pardo',
#   'number_lanes': 2,
#   'min_speed': 25,
#   'has_bus_lane': 0},
#  {'road_name': 'Carretera de Somontes al Palacio de la Real Quinta',
#   'number_lanes': 2,
#   'min_speed': 60,
#   'has_bus_lane': 0},
#  {'road_name': 'Carretera del Camino Alto de Paracuellos',
#   'number_lanes': 1,
#   'min_speed': 50,
#   'has_bus_lane': 1},
#  {'road_name': 'Cordel de Cerrastrillero',
#   'number_lanes': 2,
#   'min_speed': 60,
#   'has_bus_lane': 0},
#  {'road_name': 'GR-124;Senda Real;Camino de Santiago de Madrid;Ruta Jacobea Madrileña',
#   'number_lanes': 3,
#   'min_speed': 25,
#   'has_bus_lane': 0},
#  {'road_name': 'Glorieta de Praga',
#   'number_lanes': 4,
#   'min_speed': 50,
#   'has_bus_lane': 0},
#  {'road_name': 'M-100', 'number_lanes': 1, 'min_speed': 25, 'has_bus_lane': 1},
#  {'road_name': 'M-113', 'number_lanes': 1, 'min_speed': 25, 'has_bus_lane': 0},
#  {'road_name': 'M-12', 'number_lanes': 2, 'min_speed': 25, 'has_bus_lane': 0},
#  {'road_name': 'M-206', 'number_lanes': 4, 'min_speed': 25, 'has_bus_lane': 1},
#  {'road_name': 'M-208', 'number_lanes': 2, 'min_speed': 25, 'has_bus_lane': 1},
#  {'road_name': 'M-40', 'number_lanes': 3, 'min_speed': 25, 'has_bus_lane': 0},
#  {'road_name': 'M-406', 'number_lanes': 1, 'min_speed': 60, 'has_bus_lane': 1},
#  {'road_name': 'M-45', 'number_lanes': 4, 'min_speed': 25, 'has_bus_lane': 0},
#  {'road_name': 'M-50', 'number_lanes': 2, 'min_speed': 60, 'has_bus_lane': 1},
#  {'road_name': 'M-503', 'number_lanes': 1, 'min_speed': 25, 'has_bus_lane': 0},
#  {'road_name': 'M-509', 'number_lanes': 2, 'min_speed': 25, 'has_bus_lane': 1},
#  {'road_name': 'M-832', 'number_lanes': 3, 'min_speed': 60, 'has_bus_lane': 0},
#  {'road_name': 'Paseo de Europa',
#   'number_lanes': 2,
#   'min_speed': 50,
#   'has_bus_lane': 0},
#  {'road_name': 'Paseo de John Lennon',
#   'number_lanes': 3,
#   'min_speed': 50,
#   'has_bus_lane': 0},
#  {'road_name': 'Pista del Arroyo de Trofa',
#   'number_lanes': 3,
#   'min_speed': 50,
#   'has_bus_lane': 1},
#  {'road_name': 'Plaza de los Planetas',
#   'number_lanes': 1,
#   'min_speed': 25,
#   'has_bus_lane': 1},
#  {'road_name': 'Senda de Villanueva del Pardillo',
#   'number_lanes': 4,
#   'min_speed': 50,
#   'has_bus_lane': 1},
#  {'road_name': 'Vereda de Castilla',
#   'number_lanes': 3,
#   'min_speed': 50,
#   'has_bus_lane': 1},
#  {'road_name': 'Vereda de San Marcos',
#   'number_lanes': 4,
#   'min_speed': 50,
#   'has_bus_lane': 1},
#  {'road_name': 'Vereda de la Carrera',
#   'number_lanes': 3,
#   'min_speed': 60,
#   'has_bus_lane': 0},
#  {'road_name': 'Vereda de los Leñeros',
#   'number_lanes': 2,
#   'min_speed': 25,
#   'has_bus_lane': 0},
#  {'road_name': 'Vereda del Camino de Galapagar',
#   'number_lanes': 2,
#   'min_speed': 50,
#   'has_bus_lane': 1}]

# %% [markdown]
# ## Write out records

# %%
import json

with open('roads.json', 'w') as json_file:
    json.dump(road_records, json_file)
with open('vehicles.json', 'w') as json_file:
    json.dump(final_vehics, json_file)
